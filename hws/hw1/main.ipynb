# %% [markdown]
# # Course: Recommender Systems.
#
# ## "Intro to Collaborative Filtering" plus homework
#
# The code examples are based on T. Segaran [Programming Collective Intelligence book. Chapter 2](http://shop.oreilly.com/product/9780596529321.do)
#
# The homework task is formulated in the last cells.
#
# **Lecturer:** Dmitry Ignatov [dmitrii.ignatov@gmail.com](dmitrii.ignatov@gmail.com)
#
# **TA:** Alashaui Rafif (Alshaui.R@hse.ru), Denis Pozdnyakov (dvpozdnyakov@hse.ru), and Roman Naumkin (rinaumkin@edu.hse.ru)
#
# **Q&A:** course chat ([link](https://t.me/+PLjRelkYK74zZjYy)) or via TA's e-mail
#
# **Course channel:** ([link](https://t.me/+HYpTki0hj3VkZTgy))
#
#
# **Soft deadline** (up to 10 points): <span style="color:red">***November 16, 2025***</span>
# **Hard deadline** (-2 points):  <span style="color:blue">***November 18, 2025***</span>
#
# ---
#
# Please send your final notebooks to both teaching assistants (and lecturer in CC) with the **mandatory topic** ***[RecSys2025-HW1-RecSys-your_full_name]***.

# %% [markdown]
# # Homework 1 (RecSys). Comparison of User-based and Item-based approaches
#
# 1. Implement MAE  and RMSE as errors' estimators for [Movie Lens](http://grouplens.org/datasets/movielens/) data with 100,000 ratings (refer MoveLens100k old dataset).
# As a training set you need a file with .base extension, but a testing set has extension .test: the pairs of files u1.base and u1.test, ..., and u5.base and u5.test, respectively. Each such pair is the 80%/20% random split of the input data for all users $u$ into test and training sets.
#
# 2. For each method (user-based and item-based) plot MAE and RMSE dependence by the number of neighbours  in a range from 1 to 100 with a reasonable step.
#
# 3. Imagine that you are not satisfied with your prediction quality (e.g. MAE>1.0), then try formulas 2.6 and 2.7 from the review http://files.grouplens.org/papers/FnT%20CF%20Recsys%20Survey.pdf.
#
# There are alternative formulas: $r_{u,i} = k\sum\limits_{u^\prime \in U}\operatorname{sim}(u,u^\prime)r_{u^\prime, i} \mbox{ (the case of user-based model):}$
# $$r_{u,i} = \frac{1}{N}\sum\limits_{u^\prime \in U}r_{u^\prime, i}$$
# $$r_{u,i} = \bar{r}_u +  k\sum\limits_{u^\prime \in U} sim(u,u^\prime)(r_{u^\prime, i}-\bar{r}_{u^\prime} ) \mbox{, где } k =\frac{1}{\sum_{u^\prime \in U}|\operatorname{sim}(u,u^\prime)|}.$$
#
# 4. Compare the results as in 1 and 2.
#
# 5. How MAE (RMSE) varies by the top-$n$ size: $n \in \{1,3,5,10,15,20,30,40,50,100\}$?
#
# 6. Which movies are recommended more often --- popular with high ratings or rare ones (i.e. with low number of ratings) with high ratings?
#
# 7. What to do if the neigbourhood (similar users or items to a target user or a certain item) is too small? How to evaluate the confidence of such recommendations?
#
# 8. Describe how different the top-$n$ lists for user-based and item-based methods are, respectively. Try to improve the results by grid search on $\beta$ parameter for MAE (RMSE) minimisation in hybrid recommendations depending on the number of neighbours (or top-$n$ size):
# $$\beta\cdot r^{user-based}_{ui} + (1-\beta)\cdot r^{item-based}_{ui}, \mbox{ where } 0 \leq \beta \leq 1.$$ Report the quality in terms of MAE and RMSE along with the optimal $\beta$.

# %%
# %load_ext jupyter_black

# %% [markdown]
# ### Tasks 1-4

# %%
import os
import pandas as pd
import numpy as np


def loadMovieLens100K(path="data", subsetno=1):
    # Get movie titles
    movies = {}
    for line in open(os.path.join(path, "u.item"), encoding="iso-8859-1"):
        (idx, title) = line.split("|")[0:2]
        movies[idx] = title

    # Load data
    train = {}
    for line in open(os.path.join(path, f"u{subsetno}.base"), encoding="iso-8859-1"):
        (user, movieid, rating, ts) = line.split("\t")
        train.setdefault(user, {})
        train[user][movies[movieid]] = float(rating)
    train = pd.DataFrame.from_dict(train, orient="index")

    test = {}
    for line in open(os.path.join(path, f"u{subsetno}.test"), encoding="iso-8859-1"):
        (user, movieid, rating, ts) = line.split("\t")
        test.setdefault(user, {})
        test[user][movies[movieid]] = float(rating)
    test = pd.DataFrame.from_dict(test, orient="index")
    return (train, test)

# %%
trainItemUser, testItemUser = loadMovieLens100K()
trainUserItem, testUserItem = trainItemUser.transpose(
    copy=True
), testItemUser.transpose(copy=True)
print(f"Item-User: {testItemUser.shape}")
# Out:
# Item-User: (459, 1401)

# %%
from tqdm import tqdm


class CollaborativeFiltering:
    def __init__(self):
        pass

    def fit(self, train: pd.DataFrame):
        # Invert the preference matrix to be item-centric
        self.prefs_ = train
        self.per_item_mean = self.prefs_.mean(axis=1)
        self.per_user_mean = self.prefs_.mean(axis=0)
        self.global_mean = self.per_item_mean.mean()
        self.simScores = self.prefs_.fillna(0.0).corr() - np.eye(self.prefs_.shape[1])
        return self

    def predict(self, test, k):

        rankings = np.zeros_like(test)
        self.prefs_ = self.prefs_.fillna(0.0)
        test = test.fillna(0.0)

        for col_id, col in enumerate(tqdm(test.columns)):
            if col in self.prefs_.columns:
                top_k_closest = [
                    self.prefs_.columns[i]
                    for i in np.argsort(self.simScores.loc[col])
                    if self.prefs_.columns[i] in test.columns
                ][-k:]
            for row_id, row in enumerate(test.index):
                if col in self.prefs_.columns:
                    if row in self.prefs_.index:
                        num = np.sum(
                            [
                                self.prefs_.at[row, usr] * self.simScores.at[usr, col]
                                for usr in top_k_closest
                            ]
                        )
                        den = np.sum(
                            [self.simScores.at[usr, col] for usr in top_k_closest]
                        )
                        rankings[row_id, col_id] = num / den if den > 0 else 0.0
                    else:
                        rankings[row_id, col_id] = self.per_user_mean.at[col]
                else:
                    rankings[row_id, col_id] = (
                        self.per_item_mean.at[row]
                        if row in self.prefs_.index
                        else self.global_mean
                    )
        return pd.DataFrame(rankings, columns=test.columns, index=test.index)

# %%
class CenteredCollaborativeFiltering:
    def __init__(self):
        pass

    def fit(self, train: pd.DataFrame):
        # Invert the preference matrix to be item-centric
        self.prefs_ = train
        self.per_item_mean = self.prefs_.mean(axis=1)
        self.per_user_mean = self.prefs_.mean(axis=0)
        self.global_mean = self.per_item_mean.mean()
        self.simScores = self.prefs_.fillna(0.0).corr() - np.eye(self.prefs_.shape[1])
        return self

    def predict(self, test, k):

        rankings = np.zeros_like(test)
        self.prefs_ = self.prefs_.fillna(0.0)
        test = test.fillna(0.0)

        for col_id, col in enumerate(tqdm(test.columns)):
            if col in self.prefs_.columns:
                top_k_closest = [
                    self.prefs_.columns[i]
                    for i in np.argsort(self.simScores.loc[col])
                    if self.prefs_.columns[i] in test.columns
                ][-k:]
            for row_id, row in enumerate(test.index):
                if col in self.prefs_.columns:
                    if row in self.prefs_.index:
                        num = np.sum(
                            [
                                (self.prefs_.at[row, usr] - self.per_user_mean.at[usr])
                                * self.simScores.at[usr, col]
                                for usr in top_k_closest
                            ]
                        )
                        den = np.sum(
                            [self.simScores.at[usr, col] for usr in top_k_closest]
                        )
                        rankings[row_id, col_id] = (
                            self.per_user_mean.at[col] + num / den if den > 0 else 0.0
                        )
                    else:
                        rankings[row_id, col_id] = self.per_user_mean.at[col]
                else:
                    rankings[row_id, col_id] = (
                        self.per_item_mean.at[row]
                        if row in self.prefs_.index
                        else self.global_mean
                    )
        return pd.DataFrame(rankings, columns=test.columns, index=test.index)

# %%
import numpy as np


def mean_absolute_error(true, pred):
    return np.mean(
        np.abs(
            true.fillna(0.0).to_numpy().flatten()
            - pred.fillna(0.0).to_numpy().flatten()
        )
    )


def mean_squared_error(true, pred):
    return np.mean(
        (true.fillna(0.0).to_numpy().flatten() - pred.fillna(0.0).to_numpy().flatten())
        ** 2
    )


def rmse(true, pred):
    return np.sqrt(mean_squared_error(true, pred))


def mean_absolute_error_at_k(true, pred, k):
    true_top_k = true.fillna(0.0).to_numpy()
    true_top_k = true_top_k[np.argsort(true_top_k, axis=0)[:, -k:]]
    pred_top_k = pred.fillna(0.0).to_numpy()
    pred_top_k = pred_top_k[np.argsort(pred_top_k, axis=0)[:, -k:]]
    return np.mean(np.abs(true_top_k.flatten() - pred_top_k.flatten()))


def mean_squared_error_at_k(true, pred, k):
    true_top_k = true.fillna(0.0).to_numpy()
    true_top_k = true_top_k[np.argsort(true_top_k, axis=0)[:, -k:]]
    pred_top_k = pred.fillna(0.0).to_numpy()
    pred_top_k = pred_top_k[np.argsort(pred_top_k, axis=0)[:, -k:]]
    return np.mean((true_top_k.flatten() - pred_top_k.flatten()) ** 2)


def rmse_at_k(true, pred, k):
    return np.sqrt(mean_squared_error_at_k(true, pred, k))

# %%
UserItem_hist = []
ItemUser_hist = []
UserItemCentered_hist = []
ItemUserCentered_hist = []

IU = CollaborativeFiltering().fit(trainItemUser)
UI = CollaborativeFiltering().fit(trainUserItem)
CIU = CenteredCollaborativeFiltering().fit(trainItemUser)
CUI = CenteredCollaborativeFiltering().fit(trainUserItem)
ks = [1, 6, 11, 16, 21, 41, 61, 81]
for i in ks:
    print(f"k = {i}:")
    ItemUser_hist.append(IU.predict(testItemUser, k=i))
    UserItem_hist.append(UI.predict(testUserItem, k=i))
    ItemUserCentered_hist.append(CIU.predict(testItemUser, k=i))
    UserItemCentered_hist.append(CUI.predict(testUserItem, k=i))
# Out:
# k = 1:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 459/459 [00:09<00:00, 47.74it/s]
# k = 21:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 459/459 [01:35<00:00,  4.80it/s]
# k = 41:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 459/459 [02:59<00:00,  2.55it/s]
# k = 61:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 459/459 [04:28<00:00,  1.71it/s]
# k = 81:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 459/459 [06:00<00:00,  1.27it/s]

# %%
from matplotlib import pyplot as plt

# %matplotlib inline

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

axs[0].plot(
    ks,
    [mean_absolute_error(ui, testItemUser) for ui in ItemUser_hist],
    label="Item-based",
)
axs[0].plot(
    ks,
    [mean_absolute_error(ui, testUserItem) for ui in UserItem_hist],
    label="User-based",
)
axs[0].plot(
    ks,
    [rmse(ui, testItemUser) for ui in ItemUserCentered_hist],
    label="Item-based (centered approach)",
)
axs[0].plot(
    ks,
    [mean_absolute_error(ui, testUserItem) for ui in UserItemCentered_hist],
    label="User-based (centered approach)",
)
axs[0].set_title("MAE vs k")
axs[0].set_xlabel("Number of neighbours, k")
axs[1].plot(ks, [rmse(ui, testItemUser) for ui in ItemUser_hist], label="Item-based")
axs[1].plot(ks, [rmse(ui, testUserItem) for ui in UserItem_hist], label="User-based")
axs[1].plot(
    ks,
    [mean_absolute_error(ui, testItemUser) for ui in ItemUserCentered_hist],
    label="Item-based (centered approach)",
)
axs[1].plot(
    ks,
    [rmse(ui, testUserItem) for ui in UserItemCentered_hist],
    label="User-based (centered approach)",
)
axs[1].set_title("RMSE vs k")
axs[1].set_xlabel("Number of neighbours, k")
axs[0].legend()
axs[0].grid()
axs[1].legend()
axs[1].grid()
plt.show()

# %% [markdown]
# It is apparent that `k=16` is the optimal number of neighbours in terms of speed and recommendation accuracy since matrix plateu starting at it and it is notable that item-based approach shows better performance on this dataset. Interestingly, centered predictions do not seem to be better than those made using regular approach. Therefore predictions using item-based approach with `k=16` will be used in following tasks.

# %%
IU = CollaborativeFiltering().fit(trainItemUser)
movie_predictions = IU.predict(testItemUser, k=16)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1401/1401 [01:01<00:00, 22.70it/s]

# %% [markdown]
# ### Task 5

# %%
from matplotlib import pyplot as plt

# %matplotlib inline

fig, axs = plt.subplots(1, 2, figsize=(15, 5))
ns = [1, 3, 5, 10, 15, 20, 30, 40, 50, 100]

axs[0].plot(ns, [rmse_at_k(movie_predictions, testItemUser, n) for n in ns])
axs[0].set_title("RMSE@n")
axs[0].set_xlabel("Number of recommendations, n")
axs[1].plot(
    ns, [mean_absolute_error_at_k(movie_predictions, testItemUser, n) for n in ns]
)
axs[1].set_title("MAE@n")
axs[1].set_xlabel("Number of recommendations, n")
axs[0].grid()
axs[1].grid()
plt.show()

# %% [markdown]
# ### Task 6

# %%
n = 10  # using top-10 predictions
movie_ratings = trainItemUser.notna().sum(axis=0)
top_k_predictions_userwise = [
    movie_predictions.columns[movie_predictions.loc[usr, :].argsort()[-n:]]
    for usr in movie_predictions.index
]

# %%
movie_predictions_in_top_k = []
for movie in movie_ratings.index:
    movie_predictions_in_top_k.append(
        0
        if movie not in movie_predictions.columns
        else sum(
            [1 for recommends in top_k_predictions_userwise if movie in recommends]
        )
    )
movie_predictions_in_top_k = pd.Series(
    movie_predictions_in_top_k, index=movie_ratings.index
)

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
ax.scatter(movie_ratings, movie_predictions_in_top_k, s=50, alpha=0.7)
ax.set_title("Popularity vs recommendation frequency")
ax.set_xlabel("Popularity (number of ratings in training set)")
ax.set_ylabel("Recommendation frequency (number of times movie appeared in top-10)")
ax.set_xscale("log")
# ax.set_yscale("log")
plt.grid()
plt.show()

# %% [markdown]
# This graph implies that the more popular a movie is, the more likely it is to get recommended.

# %% [markdown]
# ### Task 7

# %% [markdown]
# - **Lower similarity threshold or increase k.** If you use a hard similarity cutoff, relax it gradually. If using top-k neighbors, increase k (with caution — more noisy neighbors).
#
# - **Significance weighting.** Weight a similarity s by $min(\frac{n}{n_0}, 1)$ where n = number of co-ratings and $n_0$ a threshold (e.g., 20). Prevents a single high similarity with tiny overlap from dominating.
#
# - **Regularized / shrinkage prediction.** Use a shrinkage term (pseudo-count) toward a global mean or baseline.
#
# - **Combine with baselines and popularity.** Fallback to item mean, user mean, or popularity ranking when neighborhood is too weak. Use a mixture model with weight proportional to neighbourhood confidence.
#
# - **Switch algorithm / use hybrid.** Use matrix factorization (SVD/ALS), factorization machines, or neural CF which do not rely on local neighbourhood density. Hybrid: blend KNN with MF or content-based features.
#
# - **Use side information (attributes / content / social graph).** Add item metadata or user attributes to expand implicit neighbourhoods.
#
# - **Use item-based rather than user-based (or vice versa).** If user-based is sparse, item-based CF often has denser co-rating structure.

# %% [markdown]
# ### Task 8

# %%
item_preds = movie_predictions
user_preds = CollaborativeFiltering().fit(trainUserItem).predict(testUserItem, k=16)
get_result = (
    lambda user_preds, item_preds, beta: beta * user_preds + (1.0 - beta) * item_preds
)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 459/459 [00:58<00:00,  7.84it/s]

# %%
from matplotlib import pyplot as plt

# %matplotlib inline

fig, axs = plt.subplots(1, 2, figsize=(15, 5))
betas = np.arange(0, 100, 5) / 100

axs[0].plot(
    betas,
    [rmse(get_result(user_preds.T, item_preds, beta), testItemUser) for beta in betas],
)
axs[0].set_title("RMSE vs beta")
axs[0].set_xlabel("beta")
axs[1].plot(
    betas,
    [
        mean_absolute_error(get_result(user_preds.T, item_preds, beta), testItemUser)
        for beta in betas
    ],
)
axs[1].set_title("MAE vs beta")
axs[1].set_xlabel("beta")
axs[0].grid()
axs[1].grid()
plt.show()

# %%
best_beta = betas[
    np.argmin(
        [
            rmse(get_result(user_preds.T, item_preds, beta), testItemUser)
            for beta in betas
        ]
    )
]
f"Best beta value: {best_beta}"
# Out:
# 'Best beta value: 0.45'
